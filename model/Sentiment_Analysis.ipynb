# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score
import joblib  # Import joblib to save the model

# %%
# Load the dataset
data = pd.read_csv("D:\HNDSE\Enterpunership Final Project\GitHub\music_ai_api-main\music_ai_api-main\Model\sentiment_Analysis.csv")
df = pd.DataFrame(data)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\H'
# <>:2: SyntaxWarning: invalid escape sequence '\H'
# C:\Users\Asset Eng\AppData\Local\Temp\ipykernel_8204\2998959366.py:2: SyntaxWarning: invalid escape sequence '\H'
#   data = pd.read_csv("D:\HNDSE\Enterpunership Final Project\GitHub\music_ai_api-main\music_ai_api-main\Model\sentiment_Analysis.csv")

# %%
data.head()
# Out:
#                          selected_text sentiment
# 0  I`d have responded, if I were going   neutral
# 1                             Sooo SAD  negative
# 2                          bullying me  negative
# 3                       leave me alone  negative
# 4                        Sons of ****,  negative

# %%
# Drop rows where X_train has NaN values
X_train = X_train.dropna()
y_train = y_train[X_train.index]  # Keep the labels aligned with the remaining data

# %%
# Replace NaN values with empty strings
X_train = X_train.fillna('')

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(df['selected_text'], df['sentiment'], test_size=0.2, random_state=42)

# %%
# Create a text classification pipeline
pipeline = Pipeline([
    ('tfidf', TfidfVectorizer()),
    ('classifier', LogisticRegression())
])

# %%
print(X_train.isna().sum())  # Check for NaN values in X_train
# Out:
# 1

# %%
X_train = X_train.fillna('')  # Fill NaN values in text data with empty strings

# %%
X_train = X_train.dropna()  # Drop rows with NaN values
y_train = y_train[X_train.index]  # Align the labels with the remaining data

# %%
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('tfidf', TfidfVectorizer()),
#                 ('classifier', LogisticRegression())])

# %%
# Save the trained pipeline as a .pkl file
joblib.dump(pipeline, 'D:/HNDSE/Enterpunership Final Project/GitHub/music_ai_api-main/music_ai_api-main/Model/sentiment_analysis.pkl')
print("Model saved as sentiment_analysis.pkl")
# Out:
# Model saved as sentiment_analysis.pkl

# %%
# Function to classify lyrics using the trained pipeline
def classify_sentiment(lyrics):
    return pipeline.predict([lyrics])[0]

# %%
# Example usage
lyrics_input = "I want to be a partner with happay"
sentiment_pred = classify_sentiment(lyrics_input)
print(f"Predicted genre: {sentiment_pred}")
# Out:
# Predicted genre: neutral
